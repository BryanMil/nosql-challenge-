# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['Garden_DB', 'admin', 'class', 'classDB', 'config', 'epa', 'fruits_db', 'local', 'met', 'test', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review the collections in our new database

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 254719,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64bfd81d83975fb0f73093ea'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254719',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
item_to_add = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(item_to_add)
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Insert the new restaurant into the collection
# ----> 2 db.establishments.insert_one(item_to_add)
#
# File c:\Users\Bryan\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:705, in Collection.insert_one(self, document, bypass_document_validation, session)
#     701     document["_id"] = ObjectId()
#     703 write_concern = self._write_concern_for(session)
#     704 return InsertOneResult(
# --> 705     self._insert(document,
#     706                  write_concern=write_concern,
#     707                  bypass_doc_val=bypass_document_validation,
#     708                  session=session),
#     709     write_concern.acknowledged)
#
# File c:\Users\Bryan\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:620, in Collection._insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     618 """Internal insert helper."""
#     619 if isinstance(docs, abc.Mapping):
# --> 620     return self._insert_one(
#     621         docs, ordered, check_keys, manipulate, write_concern, op_id,
#     622         bypass_doc_val, session)
#     624 ids = []
#     626 if manipulate:
#
# File c:\Users\Bryan\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:609, in Collection._insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     597     result = sock_info.command(
#     598         self.__database.name,
#     599         command,
#    (...)
#     604         client=self.__database.client,
#     605         retryable_write=retryable_write)
#     607     _check_write_command_response(result)
# --> 609 self.__database.client._retryable_write(
#     610     acknowledged, _insert_command, session)
#     612 if not isinstance(doc, RawBSONDocument):
#     613     return doc.get('_id')
#
# File c:\Users\Bryan\anaconda3\envs\dev\lib\site-packages\pymongo\mongo_client.py:1552, in MongoClient._retryable_write(self, retryable, func, session)
#    1550 """Internal retryable write helper."""
#    1551 with self._tmp_session(session) as s:
# -> 1552     return self._retry_with_session(retryable, func, s, None)
#
# File c:\Users\Bryan\anaconda3\envs\dev\lib\site-packages\pymongo\mongo_client.py:1438, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1429 """Execute an operation with at most one consecutive retries
#    1430
#    1431 Returns func()'s return value on success. On error retries the same
#    (...)
#    1434 Re-raises any exception thrown by func().
#    1435 """
#    1436 retryable = (retryable and self.retry_writes
#    1437              and session and not session.in_transaction)
# -> 1438 return self._retry_internal(retryable, func, session, bulk)
#
# File c:\Users\Bryan\anaconda3\envs\dev\lib\site-packages\pymongo\mongo_client.py:1470, in MongoClient._retry_internal(self, retryable, func, session, bulk)
#    1468                 raise last_error
#    1469             retryable = False
# -> 1470         return func(session, sock_info, retryable)
#    1471 except ServerSelectionTimeoutError:
#    1472     if is_retrying():
#    1473         # The application may think the write was never attempted
#    1474         # if we raise ServerSelectionTimeoutError on the retry
#    1475         # attempt. Raise the original exception instead.
#
# File c:\Users\Bryan\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:607, in Collection._insert_one.<locals>._insert_command(session, sock_info, retryable_write)
#     595     command['bypassDocumentValidation'] = True
#     597 result = sock_info.command(
#     598     self.__database.name,
#     599     command,
#    (...)
#     604     client=self.__database.client,
#     605     retryable_write=retryable_write)
# --> 607 _check_write_command_response(result)
#
# File c:\Users\Bryan\anaconda3\envs\dev\lib\site-packages\pymongo\helpers.py:229, in _check_write_command_response(result)
#     227 write_errors = result.get("writeErrors")
#     228 if write_errors:
# --> 229     _raise_last_write_error(write_errors)
#     231 error = result.get("writeConcernError")
#     232 if error:
#
# File c:\Users\Bryan\anaconda3\envs\dev\lib\site-packages\pymongo\helpers.py:210, in _raise_last_write_error(write_errors)
#     208 error = write_errors[-1]
#     209 if error.get("code") == 11000:
# --> 210     raise DuplicateKeyError(error.get("errmsg"), 11000, error)
#     211 raise WriteError(error.get("errmsg"), error.get("code"), error)
#
# DuplicateKeyError: E11000 duplicate key error collection: uk_food.establishments index: _id_ dup key: { _id: ObjectId('64bfdb873e6a46e693872e25') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: uk_food.establishments index: _id_ dup key: { _id: ObjectId('64bfdb873e6a46e693872e25') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('64bfdb873e6a46e693872e25')}}

# %%
# Check that the new restaurant was inserted
pprint(establishments.find_one({"BusinessName":item_to_add['BusinessName']}))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64bfdb873e6a46e693872e25'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': "Restaurant/Cafe/Canteen"}
fields = {'BusinessTypeID': 1, 'BusinessType': 1, 'BusinessName': 1,
          }

# Cast the results as a list and save them to a variable
results = list(establishments.find(query, fields))

# Pretty print the results
pprint(results)
# Out:
# [{'BusinessName': 'Refreshment Kiosk',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73093ea')},
#  {'BusinessName': 'FirstLight Bar & Café',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73093eb')},
#  {'BusinessName': 'The Tea Room',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73093ec')},
#  {'BusinessName': 'Lovetocater',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73093ee')},
#  {'BusinessName': "St Margaret's Bowls and Social Club",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73093f0')},
#  {'BusinessName': 'Boat House & Langdon',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73093f1')},
#  {'BusinessName': 'The Lounge Bar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73093f3')},
#  {'BusinessName': 'National Trust White Cliffs',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73093fd')},
#  {'BusinessName': 'The Halfway Hut',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309401')},
#  {'BusinessName': 'Costa Coffee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309402')},
#  {'BusinessName': 'The Barn',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309406')},
#  {'BusinessName': 'Burger King',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309408')},
#  {'BusinessName': 'The White Cliffs',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309409')},
#  {'BusinessName': 'Boodles',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730940b')},
#  {'BusinessName': 'Walmer Castle Tea Rooms',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309415')},
#  {'BusinessName': 'Mrs Knotts Tea Room',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309419')},
#  {'BusinessName': 'Table Table at Premier Inn',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730941c')},
#  {'BusinessName': 'GCP Catering Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730941d')},
#  {'BusinessName': 'Port of Dover Cargo Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309421')},
#  {'BusinessName': 'The Dover Patrol Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309424')},
#  {'BusinessName': "Mr White's English Chophouse (DMHS)",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309425')},
#  {'BusinessName': 'Cullins Yard',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309428')},
#  {'BusinessName': 'Costa Coffee, Next',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309429')},
#  {'BusinessName': 'Dover Marina Hotel',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730942a')},
#  {'BusinessName': 'Costa Coffee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730942c')},
#  {'BusinessName': 'The Pedaler on the Port',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730942e')},
#  {'BusinessName': 'Boardwalk Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309431')},
#  {'BusinessName': 'Marks and Spencer Dover Simply Food',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309434')},
#  {'BusinessName': 'Food Outlets',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309437')},
#  {'BusinessName': 'Places Leisure',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730943a')},
#  {'BusinessName': "Wheeler's Fish & Chips",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730943c')},
#  {'BusinessName': 'Kaspas',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730943d')},
#  {'BusinessName': 'Nandos',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730943f')},
#  {'BusinessName': 'German Doner Kebab',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309448')},
#  {'BusinessName': 'IL RUSTICO',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730944b')},
#  {'BusinessName': 'Taco Bell',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730944f')},
#  {'BusinessName': 'Rico Sabor',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309452')},
#  {'BusinessName': 'Cinnamon Island',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309454')},
#  {'BusinessName': 'Terrace Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309455')},
#  {'BusinessName': 'Aspendos',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309456')},
#  {'BusinessName': 'Dinos Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730945a')},
#  {'BusinessName': 'Blakes of Dover',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730945e')},
#  {'BusinessName': 'Sunrise Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730945f')},
#  {'BusinessName': 'KFC',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309462')},
#  {'BusinessName': 'Xpresso Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309464')},
#  {'BusinessName': 'Happy Chef',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309468')},
#  {'BusinessName': 'Bluebirds',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730946c')},
#  {'BusinessName': 'THENU Convenience Store',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730946e')},
#  {'BusinessName': 'Honey Pot Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309472')},
#  {'BusinessName': 'Pizza Shack',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309475')},
#  {'BusinessName': 'Chaplins',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309476')},
#  {'BusinessName': 'The Shake Shop & The Hot Dog Hut',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309477')},
#  {'BusinessName': 'Vinoteq Wine Bar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730947c')},
#  {'BusinessName': 'The Market Square Kitchen',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730947e')},
#  {'BusinessName': 'La Salle Verte',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309482')},
#  {'BusinessName': 'Cafe Melange',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309486')},
#  {'BusinessName': 'The Corner Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309487')},
#  {'BusinessName': 'MFG ESSO WALMER',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309492')},
#  {'BusinessName': 'Sea Cafe Coffee Shop',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309493')},
#  {'BusinessName': 'Tummy Station',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309495')},
#  {'BusinessName': 'The Duke Of Yorks Brewers Fayre',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309499')},
#  {'BusinessName': 'Walmer Baptist Church',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730949a')},
#  {'BusinessName': 'Buzz Bingo',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730949b')},
#  {'BusinessName': "Jane's",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094a1')},
#  {'BusinessName': 'The Haymans Kitchen',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094a4')},
#  {'BusinessName': 'The Weigh Inn',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094ad')},
#  {'BusinessName': 'The Beano Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094ae')},
#  {'BusinessName': 'Brunch Cafe Limited',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094b1')},
#  {'BusinessName': "Macari's",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094b6')},
#  {'BusinessName': 'Costa Coffee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094b8')},
#  {'BusinessName': 'Bandstand Bakery',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094b9')},
#  {'BusinessName': 'Goose on the Green',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094c0')},
#  {'BusinessName': 'Dovorian',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094c5')},
#  {'BusinessName': 'Bengal Spice',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094cc')},
#  {'BusinessName': 'St.Edmonds',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094d5')},
#  {'BusinessName': 'OAKLEYS',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094d9')},
#  {'BusinessName': 'Doyrms Coffee Shop',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094db')},
#  {'BusinessName': 'The Academy Dover',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094e6')},
#  {'BusinessName': 'Wellingtons',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094e7')},
#  {'BusinessName': 'La Scala',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094e8')},
#  {'BusinessName': 'Fish Bar & Grill',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094ea')},
#  {'BusinessName': 'Thong Dees Thai',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094f0')},
#  {'BusinessName': 'Whitecliffs Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094f1')},
#  {'BusinessName': 'Calcutta Port',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094fb')},
#  {'BusinessName': 'Pumpkin Cafe Shop',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73094ff')},
#  {'BusinessName': 'Momo Hub limited',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309502')},
#  {'BusinessName': 'Zazen Kitchen',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730950b')},
#  {'BusinessName': 'The Courtyard Oyster Bar And Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730950c')},
#  {'BusinessName': 'New Moonflower',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730950e')},
#  {'BusinessName': 'Dunkerleys Hotel & Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309510')},
#  {'BusinessName': 'HEY! Sushi',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730951b')},
#  {'BusinessName': 'The Taphouse',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309521')},
#  {'BusinessName': "Hoody's Community Cafe",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309524')},
#  {'BusinessName': 'Hoodys Community Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309526')},
#  {'BusinessName': 'Hog & Bean Deli and Eatery',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309527')},
#  {'BusinessName': 'Dylan Palace',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730952a')},
#  {'BusinessName': 'Little Harriettes of Deal',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730952f')},
#  {'BusinessName': 'The Grapevine cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309530')},
#  {'BusinessName': 'Cin Cin',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309532')},
#  {'BusinessName': 'The Lane',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309533')},
#  {'BusinessName': 'Pop Up Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309534')},
#  {'BusinessName': 'Deal Beach Parlour',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309536')},
#  {'BusinessName': 'Wellingtons',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309538')},
#  {'BusinessName': 'Sea View',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309539')},
#  {'BusinessName': 'Cabin Bar, The Clarendon Hotel',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730953a')},
#  {'BusinessName': 'The Meatball Company',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730953c')},
#  {'BusinessName': 'Aspendos',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730953f')},
#  {'BusinessName': 'Dine India, The Clarendon Hotel',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309540')},
#  {'BusinessName': 'Salentinos',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309541')},
#  {'BusinessName': 'Kings Coffee Shop',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309546')},
#  {'BusinessName': 'Starburger Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730954a')},
#  {'BusinessName': 'Strand Coffee House',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309552')},
#  {'BusinessName': 'Love Drinks',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309553')},
#  {'BusinessName': 'Peckish',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309556')},
#  {'BusinessName': 'Route One',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309558')},
#  {'BusinessName': 'Costa Coffee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730955c')},
#  {'BusinessName': 'M & Co',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309563')},
#  {'BusinessName': 'Royal Hotel',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309564')},
#  {'BusinessName': 'Starbucks',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309565')},
#  {'BusinessName': '81 Beach Street',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309566')},
#  {'BusinessName': 'Smugglers Records',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309568')},
#  {'BusinessName': 'McCarthy & Stone - Dover',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730956a')},
#  {'BusinessName': 'Milaad Tandoori Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730956e')},
#  {'BusinessName': "Kerry's Bakehouse & Eatery",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309572')},
#  {'BusinessName': 'Tides Leisure Centre',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309573')},
#  {'BusinessName': 'The Dining Club',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309576')},
#  {'BusinessName': 'Hope & Lane',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309581')},
#  {'BusinessName': 'Middle Street Fish Bar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309585')},
#  {'BusinessName': 'Frog and Scot',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730958a')},
#  {'BusinessName': 'The Three Compasses',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730958b')},
#  {'BusinessName': 'Soul Chef Kitchen',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730958c')},
#  {'BusinessName': 'Victuals & Co',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309592')},
#  {'BusinessName': 'Tea Cafe Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309595')},
#  {'BusinessName': 'Spires Bistro, The Landmark Centre',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309596')},
#  {'BusinessName': 'Kent Museum of the Moving Image',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309599')},
#  {'BusinessName': 'Miretti Pasticceria',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730959b')},
#  {'BusinessName': 'Deal Town Rangers Football Club',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73095a4')},
#  {'BusinessName': 'The Daily Grind',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73095ad')},
#  {'BusinessName': "Welly's Coffee House & Bar",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73095ae')},
#  {'BusinessName': "Welly's Coffeehouse and Bar",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73095af')},
#  {'BusinessName': 'Mileage',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73095b1')},
#  {'BusinessName': "Sid's ice cream and donut parlour",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73095b3')},
#  {'BusinessName': "Brenda's Kitchen",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73095bc')},
#  {'BusinessName': 'Trinity Church',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73095bf')},
#  {'BusinessName': 'Spindrift Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73095c7')},
#  {'BusinessName': 'Co-op',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73095c8')},
#  {'BusinessName': 'White Cliffs Tandoori',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73095dc')},
#  {'BusinessName': 'Friendship Lunch',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73095e1')},
#  {'BusinessName': 'Clay Pigeon Club',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309606')},
#  {'BusinessName': "Engel's Paradise (Bistro)",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730960b')},
#  {'BusinessName': 'Skylight Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730960e')},
#  {'BusinessName': 'One Church Dover',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309612')},
#  {'BusinessName': 'Breakwater Tap House and Pizzeria',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309614')},
#  {'BusinessName': 'The Smugglers Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309617')},
#  {'BusinessName': "Kelly's Snacks",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309626')},
#  {'BusinessName': 'Little Farthingloe Farm Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730963e')},
#  {'BusinessName': "Solley's Ice Cream Parlour",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309650')},
#  {'BusinessName': 'Pit Stop Snack Bar Unit 1',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309651')},
#  {'BusinessName': 'Dover District Leisure Centre',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730965d')},
#  {'BusinessName': 'Coombes Kitchen',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309663')},
#  {'BusinessName': 'St Radigunds Community Centre',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309666')},
#  {'BusinessName': 'Carls kitchen at caesar court',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309667')},
#  {'BusinessName': 'Dover Transport Museum',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730967a')},
#  {'BusinessName': 'KFC',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730967f')},
#  {'BusinessName': 'Sutton Vale Caravan Park And Country Club',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309686')},
#  {'BusinessName': 'The Plough Inn Beefeater',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730968a')},
#  {'BusinessName': 'Tesco Family Dining Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730968b')},
#  {'BusinessName': 'Crabble Corn Mill Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730968f')},
#  {'BusinessName': 'The Lake House Kitchen',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309696')},
#  {'BusinessName': 'The Rock Rose',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309697')},
#  {'BusinessName': 'The Truck Park Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309698')},
#  {'BusinessName': 'Galliford Try Building Ltd - Beeches',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730969c')},
#  {'BusinessName': 'Boost Kitchen',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096a1')},
#  {'BusinessName': 'Rajmahal',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096a2')},
#  {'BusinessName': 'Mcdonalds Drive Thru',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096a5')},
#  {'BusinessName': 'Bella Italia (Holiday Inn)',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096b0')},
#  {'BusinessName': 'The Lamp Room',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096b1')},
#  {'BusinessName': 'Leaf Hotel',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096b3')},
#  {'BusinessName': 'Kearsney Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096b9')},
#  {'BusinessName': 'Coombe Valley Raceway',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096c4')},
#  {'BusinessName': 'Lillyroos Glamping & camping',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096c6')},
#  {'BusinessName': 'K J Auctions',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096ca')},
#  {'BusinessName': 'Dr Legumes - Harbour Arm',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096da')},
#  {'BusinessName': 'The Pavilion',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096db')},
#  {'BusinessName': 'Custom Folkestone',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096dd')},
#  {'BusinessName': 'Barney & The Pizza',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096e3')},
#  {'BusinessName': "Dino's",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096e5')},
#  {'BusinessName': 'Harbour Coffee Company',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096f3')},
#  {'BusinessName': 'Putters!',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096fa')},
#  {'BusinessName': 'The Lighthouse Tasting Rooms',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096fd')},
#  {'BusinessName': 'Little Switzerland Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73096ff')},
#  {'BusinessName': 'The Captains Table',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309701')},
#  {'BusinessName': 'Herberts',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309702')},
#  {'BusinessName': 'Rocksalt',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309707')},
#  {'BusinessName': 'Pick Up Pintxos',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309714')},
#  {'BusinessName': 'Folklore',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730971b')},
#  {'BusinessName': 'Bella Vita',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730971d')},
#  {'BusinessName': 'Diamond Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309723')},
#  {'BusinessName': 'Touchbase Care',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309729')},
#  {'BusinessName': 'The Nook',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730972a')},
#  {'BusinessName': 'Steep Street Coffee House',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730972b')},
#  {'BusinessName': 'El Cortador',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309731')},
#  {'BusinessName': 'Big Boys Fine Burger Co',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309732')},
#  {'BusinessName': 'Misused Cocktails',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309733')},
#  {'BusinessName': 'Lucky Chip',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309735')},
#  {'BusinessName': 'The Space Bar & Gallery',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309737')},
#  {'BusinessName': 'Hillside Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309738')},
#  {'BusinessName': 'Planet Earth Kitchen',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730973b')},
#  {'BusinessName': 'Aspendos Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730973f')},
#  {'BusinessName': 'Sweet Rendezvous',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309740')},
#  {'BusinessName': 'Eleto Chocolate Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309743')},
#  {'BusinessName': 'Oriental Buffet',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309747')},
#  {'BusinessName': 'Lubens',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309748')},
#  {'BusinessName': 'Wonderland Tearoom',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309749')},
#  {'BusinessName': 'The Tearooms',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309750')},
#  {'BusinessName': 'Androus Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309751')},
#  {'BusinessName': 'Curry Garden',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730975a')},
#  {'BusinessName': 'Market Square Folkestone',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730975c')},
#  {'BusinessName': 'Luciano Pizzaria',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730975f')},
#  {'BusinessName': 'Djangos',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309760')},
#  {'BusinessName': 'Cube Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309763')},
#  {'BusinessName': 'Kathmandu House Grilled Tandoori',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309765')},
#  {'BusinessName': 'Mcdonalds Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309766')},
#  {'BusinessName': 'Sunshine Coffee and Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309767')},
#  {'BusinessName': 'RESTOCK',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730976e')},
#  {'BusinessName': 'Fireaway Pizza Folkestone',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730976f')},
#  {'BusinessName': "Grind n' Bake",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309771')},
#  {'BusinessName': 'La Princesse',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309773')},
#  {'BusinessName': 'Lilys American Diner',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309778')},
#  {'BusinessName': 'Zen Cafe Asian Diner',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309779')},
#  {'BusinessName': 'Abercrombies Community Kitchen',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730977c')},
#  {'BusinessName': 'Costa Coffee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730977f')},
#  {'BusinessName': 'The Bao Baron',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309780')},
#  {'BusinessName': 'Caffe La Delizia',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309784')},
#  {'BusinessName': 'Starbucks',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309785')},
#  {'BusinessName': 'EK Baar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309788')},
#  {'BusinessName': 'Folkestone 51',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730978a')},
#  {'BusinessName': 'KFC',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730978b')},
#  {'BusinessName': 'Blank Canvas Cafe Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309795')},
#  {'BusinessName': 'The Full English',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309798')},
#  {'BusinessName': 'Bettys Pye & Mash',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730979a')},
#  {'BusinessName': 'Burger King',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097a0')},
#  {'BusinessName': 'Cafe Tulip',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097a1')},
#  {'BusinessName': 'Asda Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097a3')},
#  {'BusinessName': 'Le Cafe Ganmac',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097a8')},
#  {'BusinessName': 'Thong-Dees',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097ac')},
#  {'BusinessName': 'Leas Cliff Hall',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097ae')},
#  {'BusinessName': 'Roccos',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097b0')},
#  {'BusinessName': 'Laurielles Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097b5')},
#  {'BusinessName': 'The Little Place......Next Door',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097b6')},
#  {'BusinessName': 'Browns Coffee House',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097b7')},
#  {'BusinessName': 'Bella Pizza & Pasta',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097b9')},
#  {'BusinessName': 'Gourmet Kitchen',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097ba')},
#  {'BusinessName': 'Papas',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097bb')},
#  {'BusinessName': 'Waves Coffee House',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097c1')},
#  {'BusinessName': 'Annapurna',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097c3')},
#  {'BusinessName': "Anna's Tearoom",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097c5')},
#  {'BusinessName': 'Food For Thought',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097ca')},
#  {'BusinessName': 'Three Hills Sports Park',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097cb')},
#  {'BusinessName': 'Genesis',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097d6')},
#  {'BusinessName': 'Sotirios Bar & Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097d8')},
#  {'BusinessName': 'The Brasserie MS',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097d9')},
#  {'BusinessName': 'The Brasserie MS',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097da')},
#  {'BusinessName': 'Rosemont Restaurant & Cocktail Bar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097de')},
#  {'BusinessName': 'Swiss Reassurance Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097e3')},
#  {'BusinessName': 'Bouverie Tap',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097e4')},
#  {'BusinessName': 'The Waterfront Cafe Bar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097e5')},
#  {'BusinessName': 'The Cider Works',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097e7')},
#  {'BusinessName': 'Conchitas',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097e9')},
#  {'BusinessName': 'Ali Baba Grill',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097ea')},
#  {'BusinessName': 'The Hideaway',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097ec')},
#  {'BusinessName': 'The Radnor Arms',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097f2')},
#  {'BusinessName': 'The View Hotel',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097f4')},
#  {'BusinessName': 'Cocomee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097f6')},
#  {'BusinessName': 'Brew',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097fc')},
#  {'BusinessName': 'Black Bull Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f73097ff')},
#  {'BusinessName': 'Sandwich Bay Bird Observatory',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730980a')},
#  {'BusinessName': 'Bridge Coffee House',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730981c')},
#  {'BusinessName': 'Grand Hotel',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309820')},
#  {'BusinessName': 'Radnor Park Lodge',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309824')},
#  {'BusinessName': 'Wards Hotel & Bistro',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309827')},
#  {'BusinessName': 'Brasserie on The Bay',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730982c')},
#  {'BusinessName': 'League of Friends Coffee Shop',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309831')},
#  {'BusinessName': 'The Marquis',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309835')},
#  {'BusinessName': 'Tunnels Tea Shop',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309847')},
#  {'BusinessName': 'The Gardeners Kitchen Tea Rooms',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730984a')},
#  {'BusinessName': 'A La Turka',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309854')},
#  {'BusinessName': 'Sorbetto',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309855')},
#  {'BusinessName': 'The Dog House & Grill',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309856')},
#  {'BusinessName': 'Alexandra Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309857')},
#  {'BusinessName': 'Thai Passion',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309863')},
#  {'BusinessName': 'Alison Sea View Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309864')},
#  {'BusinessName': 'Updown',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309867')},
#  {'BusinessName': 'Folkestone Sports Centre',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309868')},
#  {'BusinessName': "Sam's Bar",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309869')},
#  {'BusinessName': 'Royal Harbour Ramsgate Brasserie',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730986a')},
#  {'BusinessName': 'Enoteca',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730986d')},
#  {'BusinessName': 'Thanet Bowling Club',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730986e')},
#  {'BusinessName': 'Clique Bar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730986f')},
#  {'BusinessName': 'Little Ships',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309870')},
#  {'BusinessName': 'The Glass House Tea Garden',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309871')},
#  {'BusinessName': 'Travellers in Italy',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309872')},
#  {'BusinessName': 'Baker Street Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730987a')},
#  {'BusinessName': 'The Blazing Donkey',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309882')},
#  {'BusinessName': "Gerry's Coffee & Art House",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309886')},
#  {'BusinessName': 'Jah Jah',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f7309887')},
#  {'BusinessName': "Coco Latino & Clarey's Chocolates",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730988a')},
#  {'BusinessName': 'Ship Shape',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730988b')},
#  {'BusinessName': 'The Greek Arch',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730988c')},
#  {'BusinessName': 'Archive Homestore',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81d83975fb0f730988e')},
# ...
#   '_id': ObjectId('64bfd81f83975fb0f7312d9a')},
#  {'BusinessName': 'Folies',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312d9b')},
#  {'BusinessName': 'Eat Sheaf',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312da2')},
#  {'BusinessName': 'Zara Indian Dining',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312da7')},
#  {'BusinessName': 'Mountbatten',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312daa')},
#  {'BusinessName': 'Elder Street Cafe & Deli',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312db3')},
#  {'BusinessName': 'Debden Lunch Club',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312db4')},
#  {'BusinessName': 'Blues Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312db5')},
#  {'BusinessName': 'The Doorstep Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312dbd')},
#  {'BusinessName': 'Huckleberry Chicken',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312dbf')},
#  {'BusinessName': 'Tyndalls',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ddd')},
#  {'BusinessName': 'Chives Catering',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312dea')},
#  {'BusinessName': 'Costa Coffee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312deb')},
#  {'BusinessName': 'Sewards End Village Hall',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312df1')},
#  {'BusinessName': 'Just at the Station',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312df3')},
#  {'BusinessName': 'Servest Food Company',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312df4')},
#  {'BusinessName': 'Costa Coffee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312df6')},
#  {'BusinessName': 'The Boathouse Cafe Bar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312df7')},
#  {'BusinessName': 'Rosey Lea',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312dfa')},
#  {'BusinessName': 'River Palace Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312dfb')},
#  {'BusinessName': 'Cortland Fibron BX',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312dfc')},
#  {'BusinessName': 'Henry Moore Foundation Visitor Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312dfd')},
#  {'BusinessName': 'Copleys',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e01')},
#  {'BusinessName': 'Beefeater',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e0f')},
#  {'BusinessName': 'Costa Coffee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e13')},
#  {'BusinessName': 'Hi Bar Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e20')},
#  {'BusinessName': 'Hoddesdon Town Football Club',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e22')},
#  {'BusinessName': 'Chase Health and Fitness',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e26')},
#  {'BusinessName': 'Parklands Quendon Hall Events Venue',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e29')},
#  {'BusinessName': 'Quinntessential Catering',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e35')},
#  {'BusinessName': 'Turpins Indoor Bowls Club',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e36')},
#  {'BusinessName': 'Lord Butler Leisure Centre',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e38')},
#  {'BusinessName': "Fill's Cafe",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e3e')},
#  {'BusinessName': 'Wood Street Coffee Roasters Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e40')},
#  {'BusinessName': 'Hope Community Hub-Make Lunch',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e41')},
#  {'BusinessName': 'New Life Pentecostal Church',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e42')},
#  {'BusinessName': 'Jam Hospitality Limited',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e43')},
#  {'BusinessName': 'Radhuni Indian Cuisine',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e4c')},
#  {'BusinessName': 'Maltings Cafe Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e5c')},
#  {'BusinessName': 'SOKA Catering & Events Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e60')},
#  {'BusinessName': 'Wrights Fish & Chips',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e69')},
#  {'BusinessName': 'Taste Of Raj',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e74')},
#  {'BusinessName': 'Deja Vu',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e75')},
#  {'BusinessName': 'Saffron Walden Entertainments',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e77')},
#  {'BusinessName': "Fast Eddie's Community Cafe CIC (Fairycroft House)",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e7c')},
#  {'BusinessName': "Libby's Coffee Shop",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e7f')},
#  {'BusinessName': 'Khunnai Thai Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e82')},
#  {'BusinessName': "Hopley's Cafe",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e88')},
#  {'BusinessName': 'Debden Grange Retirement Village',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e89')},
#  {'BusinessName': 'Monday Muscles',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e8b')},
#  {'BusinessName': "D'Art Waffle",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e90')},
#  {'BusinessName': "Kim's Tea And Coffee House",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e99')},
#  {'BusinessName': 'Bangkok Thai Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e9d')},
#  {'BusinessName': 'Dead Time Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e9e')},
#  {'BusinessName': 'The Court Yard (Tiptree)',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312e9f')},
#  {'BusinessName': 'Starbucks Coffee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ea0')},
#  {'BusinessName': "EM's Coffee Bar",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ea3')},
#  {'BusinessName': 'The Curiosity Fair',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ea4')},
#  {'BusinessName': 'The Saffron Suite',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ea6')},
#  {'BusinessName': 'The Piano',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ea8')},
#  {'BusinessName': 'SW Baptist Church Lunch Club',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312eaa')},
#  {'BusinessName': 'Bicicletta',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312eac')},
#  {'BusinessName': 'Lokma (CK Saffron Ltd)',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312eae')},
#  {'BusinessName': 'Maze Cafe Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312eaf')},
#  {'BusinessName': 'Indigo Indian Dining',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312eb3')},
#  {'BusinessName': 'Pashas Grill',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312eb4')},
#  {'BusinessName': 'Costa',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312eb5')},
#  {'BusinessName': 'Tea Amo',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312eb7')},
#  {'BusinessName': 'Dough & Co',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312eb8')},
#  {'BusinessName': 'La Boite Ltd.',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312eb9')},
#  {'BusinessName': 'The Curious Goat',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312eba')},
#  {'BusinessName': 'Gluttons',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ebc')},
#  {'BusinessName': 'Support 4 Sight',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ebd')},
#  {'BusinessName': 'Cafe Cou Cou',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ec0')},
#  {'BusinessName': 'Jade Garden',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ec4')},
#  {'BusinessName': 'Angela Reed Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ec5')},
#  {'BusinessName': 'Mocha Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ecb')},
#  {'BusinessName': 'Joseph Barnes Wines Limited',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ecc')},
#  {'BusinessName': 'The Restaurant On Church Street',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ecd')},
#  {'BusinessName': 'Chaters',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ed0')},
#  {'BusinessName': 'St Marys C Of E Primary School',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ed5')},
#  {'BusinessName': 'Saffron Hall Bar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312edb')},
#  {'BusinessName': 'The Mogul Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312edc')},
#  {'BusinessName': 'St Marys Church',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ee8')},
#  {'BusinessName': 'Ananta',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312eef')},
#  {'BusinessName': 'Audley End Miniature Railway Cafe & Shop',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ef0')},
#  {'BusinessName': 'Audley End House \\& Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ef3')},
#  {'BusinessName': 'Wendens Ambo Pre School',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ef4')},
#  {'BusinessName': 'The Cricketers',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312ef9')},
#  {'BusinessName': 'Clavering Village Hall',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312efb')},
#  {'BusinessName': 'Brook Cottage Riding School',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312f0a')},
#  {'BusinessName': 'China Garden',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312f11')},
#  {'BusinessName': "Poppy's Tea Room",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312f12')},
#  {'BusinessName': 'Something Lovely Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312f18')},
#  {'BusinessName': 'Sliderman',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312f27')},
#  {'BusinessName': 'Leapfrogs Pre-School',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312f2b')},
#  {'BusinessName': 'March Hare Tearoom',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312f32')},
#  {'BusinessName': 'Old Swan Tea Shop',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312f33')},
#  {'BusinessName': 'Tortoise Tea Room',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312f37')},
#  {'BusinessName': 'Nuthampstead Shooting Ground',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312f3c')},
#  {'BusinessName': 'The Barn At Alswick',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312f40')},
#  {'BusinessName': 'La Vita',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64bfd81f83975fb0f7312f4b')},
#  {'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '',
#   '_id': ObjectId('64bfdb873e6a46e693872e25')}]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one(
    item_to_add,
    {'$set':
        {'BusinessTypeID': 1}
     }
)

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName': "Penang Flavours"}

results1 = list(establishments.find(query))

# Pretty print the results
pprint(results1
       )
# Out:
# [{'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'Distance': 4623.972328074718,
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': True,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64bfdb873e6a46e693872e25'),
#   'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#   'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}]

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName': 'Dover'})

# %%
# Check if any remaining documents include Dover
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('64bfd81d83975fb0f73096cf'),
#  'FHRSID': 289353,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000002468',
#  'BusinessName': 'St Marys COE (aided) Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'AddressLine1': 'St Marys Church Of England Primary School',
#  'AddressLine2': 'Warren Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6QH',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2016-09-13T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.194762', 'latitude': '51.085797'},
#  'RightToReply': '',
#  'Distance': 4591.871474174837,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/289353'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [{'$set': {'geocode.longitude': {'$toDouble': '$geocode.longitude'}, 
                                         'geocode.latitude': {'$toDouble': '$geocode.latitude'}
                                         }}])

# %%
establishments.find_one()
# Out:
# {'_id': ObjectId('64bfd81d83975fb0f73096cf'),
#  'FHRSID': 289353,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000002468',
#  'BusinessName': 'St Marys COE (aided) Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'AddressLine1': 'St Marys Church Of England Primary School',
#  'AddressLine2': 'Warren Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6QH',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2016-09-13T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.194762, 'latitude': 51.085797},
#  'RightToReply': '',
#  'Distance': 4591.871474174837,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/289353'}]}

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{'$set': {'RatingValue': {'$toInt': '$RatingValue'}                                         
                                         }}])

# %%
# Check that the coordinates and rating value are now numbers
establishments.find_one()
# Out:
# {'_id': ObjectId('64bfd81d83975fb0f73096cf'),
#  'FHRSID': 289353,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000002468',
#  'BusinessName': 'St Marys COE (aided) Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'AddressLine1': 'St Marys Church Of England Primary School',
#  'AddressLine2': 'Warren Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6QH',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2016-09-13T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.194762, 'latitude': 51.085797},
#  'RightToReply': '',
#  'Distance': 4591.871474174837,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/289353'}]}
